# %%
from collections import Counter

# %%
with open('training.txt', 'r') as f:
    train = f.read().split()
    train_set = set(train)
    
with open('test.txt', 'r') as f:
    test = f.read().split()
    test_set = set(test)

# %%
train
# Out:
# ['迈向',
#  '充满',
#  '希望',
#  '的',
#  '新',
#  '世纪',
#  '——',
#  '一九九八年',
#  '新年',
#  '讲话',
#  '（',
#  '附',
#  '图片',
#  '１',
#  '张',
#  '）',
#  '中共中央',
#  '总书记',
#  '、',
#  '国家',
#  '主席',
#  '江',
#  '泽民',
#  '（',
#  '一九九七年',
#  '十二月',
#  '三十一日',
#  '）',
#  '１２月',
#  '３１日',
#  '，',
#  '中共中央',
#  '总书记',
#  '、',
#  '国家',
#  '主席',
#  '江',
#  '泽民',
#  '发表',
#  '１９９８年',
#  '新年',
#  '讲话',
#  '《',
#  '迈向',
#  '充满',
#  '希望',
#  '的',
#  '新',
#  '世纪',
#  '》',
#  '。',
#  '（',
#  '新华社',
#  '记者',
#  '兰',
#  '红光',
#  '摄',
#  '）',
#  '同胞',
#  '们',
#  '、',
#  '朋友',
#  '们',
#  '、',
#  '女士',
#  '们',
#  '、',
#  '先生',
#  '们',
#  '：',
#  '在',
#  '１９９８年',
#  '来临',
#  '之际',
#  '，',
#  '我',
#  '十分',
#  '高兴',
#  '地',
#  '通过',
#  '中央',
#  '人民',
#  '广播',
#  '电台',
#  '、',
#  '中国',
#  '国际',
#  '广播',
#  '电台',
#  '和',
#  '中央',
#  '电视台',
#  '，',
#  '向',
#  '全国',
#  '各族',
#  '人民',
#  '，',
#  '向',
#  '香港',
#  '特别',
#  '行政区',
#  '同胞',
#  '、',
#  '澳门',
#  '和',
#  '台湾',
#  '同胞',
#  '、',
#  '海外',
#  '侨胞',
#  '，',
#  '向',
# ...

# %%
len(train)
# Out:
# 1109947

# %%
train_count = Counter(train)

# %%
train_count
# Out:
# Counter({'迈向': 33,
#          '充满': 115,
#          '希望': 492,
#          '的': 53891,
#          '新': 2274,
#          '世纪': 419,
#          '——': 153,
#          '一九九八年': 39,
#          '新年': 271,
#          '讲话': 233,
#          '（': 4265,
#          '附': 289,
#          '图片': 615,
#          '１': 579,
#          '张': 1218,
#          '）': 4265,
#          '中共中央': 226,
#          '总书记': 96,
#          '、': 22979,
#          '国家': 2024,
#          '主席': 637,
#          '江': 601,
#          '泽民': 450,
#          '一九九七年': 58,
#          '十二月': 26,
#          '三十一日': 11,
#          '１２月': 236,
#          '３１日': 57,
#          '，': 74141,
#          '发表': 299,
#          '１９９８年': 309,
#          '《': 1923,
#          '》': 1923,
#          '。': 35603,
#          '新华社': 1161,
#          '记者': 2113,
#          '兰': 18,
#          '红光': 5,
#          '摄': 359,
#          '同胞': 144,
#          '们': 848,
#          '朋友': 157,
#          '女士': 41,
#          '先生': 155,
#          '：': 3197,
# ...

# %%
len(train_count)
# Out:
# 55303

# %%
len(test)
# Out:
# 104372

# %%
test_count = Counter(test)

# %%
test_count
# Out:
# Counter({'共同': 48,
#          '创造': 46,
#          '美好': 23,
#          '的': 5095,
#          '新': 554,
#          '世纪': 444,
#          '——': 6,
#          '二○○一年': 4,
#          '新年': 66,
#          '贺词': 7,
#          '（': 374,
#          '二○○○年': 6,
#          '十二月': 10,
#          '三十一日': 4,
#          '）': 375,
#          '附': 25,
#          '图片': 67,
#          '1': 49,
#          '张': 77,
#          '女士': 2,
#          '们': 74,
#          '，': 6825,
#          '先生': 14,
#          '同志': 48,
#          '朋友': 19,
#          '：': 346,
#          '2001年': 54,
#          '钟声': 14,
#          '即将': 13,
#          '敲响': 9,
#          '。': 3425,
#          '人类': 50,
#          '社会': 145,
#          '前进': 22,
#          '航船': 2,
#          '就要': 4,
#          '驶入': 2,
#          '21': 34,
#          '航程': 1,
#          '中国': 377,
#          '人民': 245,
#          '进入': 42,
#          '了': 983,
#          '向': 159,
#          '现代化': 73,
#          '建设': 206,
#          '第三': 33,
# ...

# %%
len(test_count)
# Out:
# 13148

# %%
len(set(test) - set(train))
# Out:
# 2863

# %%
dic = {}
for s in (set(test) - set(train)):
    dic[s] = test_count[s]

# %%
dic
# Out:
# {'马钢': 1,
#  '感光': 1,
#  '定局': 2,
#  '朝发夕至': 2,
#  '首脑会': 1,
#  '10': 54,
#  '最快': 1,
#  '区县': 1,
#  '8500': 1,
#  '进香团': 2,
#  '农办': 1,
#  '百分之六七十': 1,
#  '89.9％': 1,
#  '大嶝': 2,
#  '惠及': 1,
#  '8.9万': 1,
#  '五河': 1,
#  '1日': 109,
#  '玉带': 1,
#  '总的': 2,
#  '嗣后': 1,
#  '伏全': 1,
#  '50亿': 2,
#  '外围赛': 2,
#  '听觉': 1,
#  '鹿城区': 1,
#  '毁林': 1,
#  '量力': 1,
#  '蒙特马里奥': 1,
#  '关税率': 1,
#  '灵柩': 2,
#  '比肩而立': 1,
#  '婚典': 1,
#  '为国捐躯': 1,
#  '13': 8,
#  '30％': 3,
#  '一面之词': 1,
#  '2465．85万': 1,
#  '任免权': 3,
#  '红柳': 1,
#  '王水圩村': 1,
#  '十方镇': 1,
#  '暴利': 1,
#  '477': 1,
#  '还政于民': 1,
#  '541.54万': 1,
#  '寮步镇': 1,
#  '119': 1,
#  '683': 1,
#  '穆沙拉夫': 1,
#  '三河': 1,
#  '百分之七十一': 1,
#  '任人唯贤': 2,
#  '金钢': 1,
#  '祝酒辞': 2,
#  '9时': 6,
#  '510': 1,
#  '七千一百六十三': 1,
#  '推介会': 1,
#  '背包绳': 1,
#  '10万': 5,
#  '27日': 1,
#  '统计处': 1,
#  '龌龊': 1,
#  '12时': 3,
#  '地方税': 2,
#  '阿克马塔利耶夫': 1,
#  '法赫德': 1,
#  '金家庄': 2,
#  '福源': 1,
#  '连降': 1,
#  '二十八万': 1,
#  '行将就木': 1,
#  '－1': 4,
#  '访问量': 1,
#  '农网': 1,
# ...

# %%
len(dic)
# Out:
# 2863
